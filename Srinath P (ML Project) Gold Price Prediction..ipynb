# %% [markdown]
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# # View the Dataset

# %%
df = pd.read_csv('C:\\Users\\frgs\\Downloads\\gld_price_data.csv')

# %%
df
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %% [markdown]
# # check the top 5 records of the dataset

# %%
df.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %% [markdown]
# # check the top 5 records of the dataset

# %%
df.tail()
# Out:
#            Date          SPX         GLD      USO      SLV   EUR/USD
# 2285   5/8/2018  2671.919922  124.589996  14.0600  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.3700  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.4100  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.3800  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.4058  15.4542  1.182033

# %% [markdown]
# # check the shape of dataset

# %%
df.shape
# Out:
# (2290, 6)

# %% [markdown]
# # shape or dimensions of the datasets,

# %%
print('The Shape or Dimensions of the dataset having the rows of "{}" and Columns of "{}".'. format(df.shape[0], df.shape[1]))
# Out:
# The Shape or Dimensions of the dataset having the rows of "2290" and Columns of "6".

# %% [markdown]
# # Information of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
#check the null values!

# %%
df.isna().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %% [markdown]
# #now the dataset has no null values

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303296
# 75%    2073.010070   132.840004    37.827501    22.882499     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %% [markdown]
# # SPX - Attribute

# %%
print('Column_name : ' ,df.iloc[:,1].name)
print('Type : ',df.iloc[:,1].dtype)

print('Null_value_count: ',df.iloc[:,1].isna().sum())
# Out:
# Column_name :  SPX
# Type :  float64
# Null_value_count:  0

# %%
print('Skewness: ', df.iloc[:,1].skew())
df.iloc[:,1].describe()
# Out:
# Skewness:  0.3003618142394941
# count    2290.000000
# mean     1654.315776
# std       519.111540
# min       676.530029
# 25%      1239.874969
# 50%      1551.434998
# 75%      2073.010070
# max      2872.870117
# Name: SPX, dtype: float64

# %%
plt.subplot(1,2,1)
sns.boxplot(df.iloc[:,1], color = 'green')
plt.xlabel(df.iloc[:,1].name, fontsize = 20)
plt.title('Boxplot_ '+ df.iloc[:,1].name, fontsize = 15)
plt.subplot(1,2,2)
plt.hist(df.iloc[:,1], color = 'skyblue')
plt.xlabel(df.iloc[:,1].name, fontsize = 20)
plt.title('Histogram_ '+ df.iloc[:,1].name, fontsize = 15)
plt.subplots_adjust(left=0.4, bottom=0.1, right=2.2, top=1.2)

# %% [markdown]
# Through skewness. Box-plot and Histogram plot found that the Day has no outliers in its dataset.

# %% [markdown]
# # GLD -  ATTRIBUTE

# %%
print('Column_name : ' ,df.iloc[:,2].name)
print('Type : ',df.iloc[:,2].dtype)

print('Null_value_count: ',df.iloc[:,2].isna().sum())
# Out:
# Column_name :  GLD
# Type :  float64
# Null_value_count:  0

# %%
print('Skewness: ', df.iloc[:,2].skew())
df.iloc[:,2].describe()
# Out:
# Skewness:  0.33413834726925085
# count    2290.000000
# mean      122.732875
# std        23.283346
# min        70.000000
# 25%       109.725000
# 50%       120.580002
# 75%       132.840004
# max       184.589996
# Name: GLD, dtype: float64

# %%
plt.subplot(1,2,1)
sns.boxplot(df.iloc[:,2], color = 'green')
plt.xlabel(df.iloc[:,2].name, fontsize = 20)
plt.title('Boxplot_ '+ df.iloc[:,2].name, fontsize = 15)
plt.subplot(1,2,2)
plt.hist(df.iloc[:,2], color = 'skyblue')
plt.xlabel(df.iloc[:,2].name, fontsize = 20)
plt.title('Histogram_ '+ df.iloc[:,2].name, fontsize = 15)
plt.subplots_adjust(left=0.4, bottom=0.1, right=2.2, top=1.2)

# %% [markdown]
# # USO - Attribute

# %%
print('Column_name : ' ,df.iloc[:,3].name)
print('Type : ',df.iloc[:,3].dtype)

print('Null_value_count: ',df.iloc[:,3].isna().sum())
# Out:
# Column_name :  USO
# Type :  float64
# Null_value_count:  0

# %%
print('Skewness: ', df.iloc[:,3].skew())
df.iloc[:,3].describe()
# Out:
# Skewness:  1.6993309916429746
# count    2290.000000
# mean       31.842221
# std        19.523517
# min         7.960000
# 25%        14.380000
# 50%        33.869999
# 75%        37.827501
# max       117.480003
# Name: USO, dtype: float64

# %%
plt.subplot(1,2,1)
sns.boxplot(df.iloc[:,3], color = 'green')
plt.xlabel(df.iloc[:,3].name, fontsize = 20)
plt.title('Boxplot_ '+ df.iloc[:,3].name, fontsize = 15)
plt.subplot(1,2,2)
plt.hist(df.iloc[:,3], color = 'skyblue')
plt.xlabel(df.iloc[:,3].name, fontsize = 20)
plt.title('Histogram_ '+ df.iloc[:,3].name, fontsize = 15)
plt.subplots_adjust(left=0.4, bottom=0.1, right=2.2, top=1.2)

# %% [markdown]
# # SLVR - Attribute

# %%
print('Column_name : ' ,df.iloc[:,4].name)
print('Type : ',df.iloc[:,4].dtype)

print('Null_value_count: ',df.iloc[:,4].isna().sum())
# Out:
# Column_name :  SLV
# Type :  float64
# Null_value_count:  0

# %%
print('Skewness: ', df.iloc[:,4].skew())
df.iloc[:,4].describe()
# Out:
# Skewness:  1.1536409144141129
# count    2290.000000
# mean       20.084997
# std         7.092566
# min         8.850000
# 25%        15.570000
# 50%        17.268500
# 75%        22.882499
# max        47.259998
# Name: SLV, dtype: float64

# %%
plt.subplot(1,2,1)
sns.boxplot(df.iloc[:,4], color = 'green')
plt.xlabel(df.iloc[:,4].name, fontsize = 20)
plt.title('Boxplot_ '+ df.iloc[:,4].name, fontsize = 15)
plt.subplot(1,2,2)
plt.hist(df.iloc[:,4], color = 'skyblue')
plt.xlabel(df.iloc[:,4].name, fontsize = 20)
plt.title('Histogram_ '+ df.iloc[:,4].name, fontsize = 15)
plt.subplots_adjust(left=0.4, bottom=0.1, right=2.2, top=1.2)

# %% [markdown]
# # EUR/USD - Attribute

# %%
print('Column_name : ' ,df.iloc[:,5].name)
print('Type : ',df.iloc[:,5].dtype)

print('Null_value_count: ',df.iloc[:,5].isna().sum())
# Out:
# Column_name :  EUR/USD
# Type :  float64
# Null_value_count:  0

# %%
print('Skewness: ', df.iloc[:,5].skew())
df.iloc[:,5].describe()
# Out:
# Skewness:  -0.005292277033840852
# count    2290.000000
# mean        1.283653
# std         0.131547
# min         1.039047
# 25%         1.171313
# 50%         1.303296
# 75%         1.369971
# max         1.598798
# Name: EUR/USD, dtype: float64

# %%
plt.subplot(1,2,1)
sns.boxplot(df.iloc[:,5], color = 'green')
plt.xlabel(df.iloc[:,5].name, fontsize = 20)
plt.title('Boxplot_ '+ df.iloc[:,5].name, fontsize = 15)
plt.subplot(1,2,2)
plt.hist(df.iloc[:,5], color = 'skyblue')
plt.xlabel(df.iloc[:,5].name, fontsize = 20)
plt.title('Histogram_ '+ df.iloc[:,5].name, fontsize = 15)
plt.subplots_adjust(left=0.4, bottom=0.1, right=2.2, top=1.2)

# %% [markdown]
# # Visulization

# %%
#Heat map plot

# %%
f = plt.figure(figsize=(10, 10))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %% [markdown]
# ## Correlation plot!

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_6949edda_ccc5_11eb_a744_204747256792row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row0_col1 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row1_col0 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row1_col2 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row1_col3 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row1_col4 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row2_col0 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row2_col3 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row2_col4 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row3_col0 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row3_col1 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row3_col2 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row3_col4 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row4_col1 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row4_col2 {
#             background-color:  #d85646;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row4_col3 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_6949edda_ccc5_11eb_a744_204747256792row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_6949edda_ccc5_11eb_a744_204747256792" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SPX</th>        <th class="col_heading level0 col1" >GLD</th>        <th class="col_heading level0 col2" >USO</th>        <th class="col_heading level0 col3" >SLV</th>        <th class="col_heading level0 col4" >EUR/USD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6949edda_ccc5_11eb_a744_204747256792level0_row0" class="row_heading level0 row0" >SPX</th>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row0_col1" class="data row0 col1" >0.05</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row0_col2" class="data row0 col2" >-0.59</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row0_col3" class="data row0 col3" >-0.27</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row0_col4" class="data row0 col4" >-0.67</td>
#             </tr>
#             <tr>
#                         <th id="T_6949edda_ccc5_11eb_a744_204747256792level0_row1" class="row_heading level0 row1" >GLD</th>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row1_col0" class="data row1 col0" >0.05</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row1_col2" class="data row1 col2" >-0.19</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row1_col3" class="data row1 col3" >0.87</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row1_col4" class="data row1 col4" >-0.02</td>
#             </tr>
#             <tr>
#                         <th id="T_6949edda_ccc5_11eb_a744_204747256792level0_row2" class="row_heading level0 row2" >USO</th>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row2_col0" class="data row2 col0" >-0.59</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row2_col1" class="data row2 col1" >-0.19</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row2_col3" class="data row2 col3" >0.17</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row2_col4" class="data row2 col4" >0.83</td>
#             </tr>
#             <tr>
#                         <th id="T_6949edda_ccc5_11eb_a744_204747256792level0_row3" class="row_heading level0 row3" >SLV</th>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row3_col0" class="data row3 col0" >-0.27</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row3_col1" class="data row3 col1" >0.87</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row3_col2" class="data row3 col2" >0.17</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row3_col4" class="data row3 col4" >0.32</td>
#             </tr>
#             <tr>
#                         <th id="T_6949edda_ccc5_11eb_a744_204747256792level0_row4" class="row_heading level0 row4" >EUR/USD</th>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row4_col0" class="data row4 col0" >-0.67</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row4_col1" class="data row4 col1" >-0.02</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row4_col2" class="data row4 col2" >0.83</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row4_col3" class="data row4 col3" >0.32</td>
#                         <td id="T_6949edda_ccc5_11eb_a744_204747256792row4_col4" class="data row4 col4" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
#Now see the correlation matrix and heatmap
import matplotlib.pyplot as plt
import seaborn as sns
corr = df.corr()
plt.figure(figsize = (6,5))
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            annot=True,fmt='.2f',linewidths=0.30)
plt.title('Correlation of df Features', y = 1.05, size=15)
# Out:
# Text(0.5, 1.05, 'Correlation of df Features')

# %%
#Lets look the correlation score
print (corr['GLD'].sort_values(ascending=False), '\n')
# Out:
# GLD        1.000000
# SLV        0.866632
# SPX        0.049345
# EUR/USD   -0.024375
# USO       -0.186360
# Name: GLD, dtype: float64

# %%
sns.pairplot(df)

# %%
#Lets Check our target variable
sns.distplot(df['GLD'], color = 'blue')
print('Skewness: %f', df['GLD'].skew())
print("Kurtosis: %f" % df['GLD'].kurt())
# Out:
# Skewness: %f 0.33413834726925085
# Kurtosis: -0.275081

# %%
#Now we check the relation with GLD variable
sns.jointplot(x =df['SLV'], y = df['GLD'], color = 'deeppink')

# %%
#Now we check the relation with GLD variable
sns.jointplot(x =df['SPX'], y = df['GLD'], color = 'purple')

# %% [markdown]
# # Create a Machine Learning Model

# %%
# Now lets take our matrix of feature and target
x_trail = df[['SPX','USO','SLV','EUR/USD']]
x = x_trail.iloc[:, :].values
y = df.iloc[:, 2].values

# %% [markdown]
# # Spliting the dataset into training and test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# #
.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE :   1.2983245973580806
# MSE :   5.115777598941889
# RMAE :   2.2618084797218994

# %%
error_score = metrics.r2_score(y_test,y_pred)
print('R Squared error :', error_score)
# Out:
# R Squared error : 0.9900558191821279

# %%
#Now Lets Check the Training and Test set Accuracy

# %%
accuracy_train = regressor.score(x_train, y_train)
accuracy_test = regressor.score(x_test, y_test)
print(accuracy_train)
print(accuracy_test)
# Out:
# 0.9984218332175093
# 0.9900558191821279

# %% [markdown]
# # Visualising the Accuracy of Predicted result

# %%
plt.plot(y_test, color = 'blue', label = 'Acutal')
plt.plot(y_pred, color = 'Red', label = 'Predicted')
plt.grid(0.3)
plt.title('Acutal vs Predicted')
plt.xlabel('Number of Oberservation')
plt.ylabel('GLD')
plt.legend()
plt.show()

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#getting the coefficients after the regression

# %%
lm.coef_
# Out:
# array([ 6.81141246e-03, -2.44980516e-01,  3.19962417e+00, -1.05039668e+01])

# %%
#printing the intercept/

# %%
print(lm.intercept_)
# Out:
# 68.5632885751738

# %%
y_pred = lm.predict(x_test)

# %%
error_score = metrics.r2_score(y_test,y_pred)
print('R Squared error :', error_score)
# Out:
# R Squared error : 0.8530125466873725

# %%
plt.plot(y_test, color = 'blue', label = 'Acutal')
plt.plot(y_pred, color = 'deeppink', label = 'Predicted')
plt.grid(0.3)
plt.title('Acutal vs Predicted')
plt.xlabel('Number of Oberservation')
plt.ylabel('GLD')
plt.legend()
plt.show()

# %%
accuracy_train = lm.score(x_train, y_train)
accuracy_test = lm.score(x_test, y_test)
print(accuracy_train)
print(accuracy_test)
# Out:
# 0.8877758904855643
# 0.8530125466873725

# %% [markdown]
# # Visualization

# %%
predictions = lm.predict(x_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
 plt.plot(y_test,predictions,linestyle='solid')

# %% [markdown]
# # check the error for Regression

# %%
from sklearn import metrics
print('MAE :'," ", metrics.mean_absolute_error(y_test,predictions))
print('MSE :'," ", metrics.mean_squared_error(y_test,predictions))
print('RMAE :'," ", np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# MAE :   6.112232362039988
# MSE :   75.61760337571634
# RMAE :   8.695838279068692

# %%
sns.distplot(y_test - predictions,bins=50)

# %% [markdown]
# # Decision Tree

# %%
# import the regressor
from sklearn.tree import DecisionTreeRegressor

# %%
# create a regressor object
regressor = DecisionTreeRegressor(random_state = 0)

# %%
# fit the regressor with X and Y data

# %%
regressor.fit(x, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# predicting a new value

# %%
# test the output by changing values
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([128.789993, 115.620003, 139.220001, 120.93    ,  93.040001,
#        154.649994, 116.720001, 113.029999, 149.740005, 104.800003,
#        103.709999, 119.660004,  91.18    , 159.669998, 121.629997,
#        116.43    ,  88.949997,  91.610001,  93.269997, 127.849998,
#         79.199997, 118.470001, 126.339996, 175.779999, 174.580002,
#        138.539993, 114.099998, 160.460007, 134.830002, 113.830002,
#        110.470001, 105.489998, 128.679993, 122.760002,  97.699997,
#        122.290001,  85.07    , 115.470001, 128.380005, 139.259995,
#        103.919998, 127.93    , 108.32    , 134.369995, 134.179993,
#        110.82    ,  79.75    ,  70.      , 119.169998, 120.580002,
#         91.75    , 110.82    , 117.07    , 117.139999, 123.650002,
#        147.830002,  86.709999, 130.990005, 117.410004, 156.25    ,
#        109.129997, 154.869995, 123.989998, 114.459999, 115.32    ,
#        124.870003, 134.089996, 139.860001, 116.089996, 127.660004,
#         93.760002, 115.199997,  90.040001,  89.709999, 106.949997,
#        134.070007, 149.460007, 161.080002, 121.959999, 101.860001,
#        103.949997, 150.990005, 153.759995, 107.669998, 135.199997,
#        123.709999, 126.160004,  88.800003, 177.720001, 116.360001,
#        135.110001, 114.43    ,  85.970001, 122.599998, 131.309998,
#        116.330002, 134.100006, 120.760002, 172.229996, 121.309998,
#        122.279999, 120.940002, 126.809998,  88.25    , 147.729996,
#        112.290001, 111.730003, 110.449997, 157.119995,  92.790001,
#         93.239998, 117.980003, 157.929993, 120.389999, 155.130005,
#        126.139999, 161.570007, 124.360001, 130.100006, 124.389999,
#         71.709999,  93.709999,  90.040001, 122.080002, 110.82    ,
#        118.68    , 107.519997, 125.699997, 126.230003, 121.639999,
#        121.110001, 104.260002, 110.809998, 111.089996, 149.199997,
#        125.620003, 135.039993, 126.239998, 139.139999, 141.919998,
#        108.279999, 109.589996, 130.169998, 108.349998, 115.779999,
#        122.82    , 148.220001,  94.599998, 104.669998, 128.110001,
#        126.470001, 163.210007, 122.080002, 150.410004, 109.139999,
#        124.730003,  87.68    ,  80.760002, 128.470001, 125.419998,
#        138.      , 119.760002, 127.699997,  85.82    , 123.919998,
#        120.050003, 115.779999, 102.269997, 121.650002,  93.849998,
#        102.339996, 124.669998, 115.029999, 126.449997,  89.589996,
#        119.730003, 108.470001, 120.989998, 133.490005,  87.269997,
#        123.620003, 102.260002, 102.529999, 103.150002,  88.139999,
#        120.139999, 122.830002, 169.050003, 126.620003,  95.730003,
#        161.529999, 108.620003,  97.239998, 130.449997, 114.389999,
#         85.809998, 167.179993,  90.120003,  90.57    , 167.289993,
#        161.029999, 165.649994, 168.710007, 126.18    , 127.019997,
#        122.209999,  91.449997, 122.019997, 120.360001, 129.130005,
#        159.869995, 117.339996, 106.379997])

# %%
from sklearn import metrics
print('MAE :'," ", metrics.mean_absolute_error(y_test,y_pred))
print('MSE :'," ", metrics.mean_squared_error(y_test,y_pred))
print('RMAE :'," ", np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE :   0.0
# MSE :   0.0
# RMAE :   0.0

# %%
error_score = metrics.r2_score(y_test,y_pred)
print('R Squared error :', error_score)
# Out:
# R Squared error : 1.0

# %%
accuracy_train = regressor.score(x_train, y_train)
accuracy_test = regressor.score(x_test, y_test)
print(accuracy_train)
print(accuracy_test)
# Out:
# 1.0
# 1.0

# %% [markdown]
# # Visualizing accuracy and Prediction

# %%
plt.plot(y_test, color = 'blue', label = 'Acutal')
plt.plot(y_pred, color = 'deeppink', label = 'Predicted')
plt.grid(0.3)
plt.title('Acutal vs Predicted')
plt.xlabel('Number of Oberservation')
plt.ylabel('GLD')
plt.legend()
plt.show()

# %% [markdown]
# # finally, compare all alogirthm decision tree gave a good prediction so i take it as a final model.
